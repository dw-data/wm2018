# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import re
import os
import requests
import dateutil
from datetime import datetime

pd.set_option("display.max_rows", 1000)

plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

# %%
overview_page_urls = ["http://www.kicker.de/news/fussball/weltmeisterschaft/spiele/weltmeisterschaft/2018/4/0/spieltag.html"]

# %%
url_list = []
tactical_url_list = []
names_list = []

for url in overview_page_urls:
    #open each of the overview pages
    requested_page = Request(url, headers={'User-Agent': 'Chrome/64.0'})
    webpage = urlopen(requested_page).read()
    overview_page = BeautifulSoup(webpage, "html.parser")
    
    #Find the links to all the pages that contain an analysis
    for a in overview_page.findAll('a', {'class': 'link'}):
        if a.text == "Analyse":
            print(a['href'])
            url_list.append(a['href'])
        if  a.text == "Spielbericht":
            print(a['href'])
            url_list.append(a['href'])
    
    #For each of the found links, replace part of the URL to head to the tactical setup and save it as a new URL
    for url in url_list:
        modified_url = url.replace('spielanalyse','taktische-aufstellung').replace('spielbericht','taktische-aufstellung')
        full_url = 'http://www.kicker.de'+modified_url
        print(full_url)
        tactical_url_list.append(full_url)
        
    for tactical_url in tactical_url_list:
        #open the URL for each game's tactical set up listing all players and exchanged players
        requested_page_two = Request(tactical_url)
        webpage_two = urlopen(requested_page_two).read()
        overview_page_two = BeautifulSoup(webpage_two, "html.parser")

        #find all the names listed on the page and add them to the list
        #search by div-id as that is the only way to exclude the players on the Ersatzbank
        for div in overview_page_two.findAll('div', {'id':'ctl00_PlaceHolderHalf_aufstellunghalf_ausstellungHeim'}):
            for a in div.findAll('a', {'class':'link_noicon'}):
                print(a.text)
                names_list.append(a.text)

        for div in overview_page_two.findAll('div', {'id':'ctl00_PlaceHolderHalf_aufstellunghalf_einwechslungenHeim'}):
            for a in div.findAll('a', {'class':'link_noicon'}):
                print(a.text)
                names_list.append(a.text)

        for div in overview_page_two.findAll('div', {'id':'ctl00_PlaceHolderHalf_aufstellunghalf_ausstellungAusw'}):
            for a in div.findAll('a', {'class':'link_noicon'}):
                print(a.text)
                names_list.append(a.text)

        for div in overview_page_two.findAll('div', {'id':'ctl00_PlaceHolderHalf_aufstellunghalf_einwechslungenAusw'}):
            for a in div.findAll('a', {'class':'link_noicon'}):
                print(a.text)
                names_list.append(a.text)
# Out:
# /news/fussball/weltmeisterschaft/spiele/weltmeisterschaft/2018/4/3070455/spielanalyse_frankreich_argentinien.html
# /news/fussball/weltmeisterschaft/spiele/weltmeisterschaft/2018/4/3070454/spielanalyse_uruguay_portugal.html
# /news/fussball/weltmeisterschaft/spiele/weltmeisterschaft/2018/4/3070456/spielanalyse_spanien-932_russland.html
# /news/fussball/weltmeisterschaft/spiele/weltmeisterschaft/2018/4/3070457/spielanalyse_kroatien_daenemark.html
# /news/fussball/weltmeisterschaft/spiele/weltmeisterschaft/2018/4/3070459/spielanalyse_brasilien-920_mexiko.html
# Dzyuba
# Granat
# Zhirkov
# Cheryshev
# Samedov
# Smolov
# Dzyuba
# Erokhin
# Kuzyaev
# Subasic
# Vrsaljko
# Lovren
# Vida
# Strinic
# Rakitic
# Brozovic
# Modric
# Rebic
# Perisic
# Mandzukic
# Kovacic
# Brozovic
# Pivaric
# Strinic
# Kramaric
# Perisic
# Badelj
# Mandzukic
# Schmeichel
# Dalsgaard
# Kjaer
# M. Jörgensen
# Knudsen
# A. Christensen
# Delaney
# Eriksen
# Y. Poulsen
# Braithwaite
# Cornelius
# Schöne
# A. Christensen
# N. Jörgensen
# Cornelius
# Krohn-Dehli
# Delaney
# Sisto
# Braithwaite
# Alisson
# Fagner
# Thiago Silva
# Miranda
# Filipe Luis
# Casemiro
# Paulinho
# Coutinho
# Willian
# Neymar
# Gabriel Jesus
# Fernandinho
# Paulinho
# Roberto Firmino
# Coutinho
# Marquinhos
# Willian
# Ochoa
# Alvarez
# Ayala
# Salcedo
# Gallardo
# Marquez
# Herrera
# Guardado
# Lozano
# Vela
# Chicharito
# Layun
# Marquez
# J. dos Santos
# Alvarez
# Raul Jimenez
# Chicharito
# Courtois
# Alderweireld
# Kompany
# Vertonghen
# Meunier
# De Bruyne
# Witsel
# Carrasco
# Mertens
# E. Hazard
# R. Lukaku
# Fellaini
# Mertens
# Chadli
# Carrasco
# Kawashima
# H. Sakai
# Yoshida
# Shoji
# Nagatomo
# Hasebe
# Shibasaki
# Haraguchi
# Inui
# Kagawa
# Osako
# Yamaguchi
# Shibasaki
# Honda
# Haraguchi
# Olsen
# Lustig
# Lindelöf
# Granqvist
# Augustinsson
# G. Svensson
# Ekdal
# Claesson
# Forsberg
# Berg
# Toivonen
# Martin Olsson
# Forsberg
# Krafth
# Lustig
# Kiese Thelin
# Berg
# Sommer
# Lang
# Djourou
# Akanji
# R. Rodriguez
# Behrami
# G. Xhaka
# Shaqiri
# Dzemaili
# Zuber
# Drmic
# Embolo
# Zuber
# Seferovic
# Dzemaili
# Ospina
# Arias
# Yerry Mina
# D. Sanchez
# Mojica
# C. Sanchez
# Barrios
# Ju. Cuadrado
# Quintero
# Jefferson Lerma
# Falcao
# Bacca
# Jefferson Lerma
# Uribe
# C. Sanchez
# Muriel
# Quintero
# Zapata
# Arias
# Pickford
# Walker
# Stones
# Maguire
# J. Henderson
# Trippier
# Alli
# Lingard
# A. Young
# Sterling
# H. Kane
# Dier
# Alli
# Vardy
# Sterling
# D. Rose
# A. Young
# Rashford
# Walker

# %%
df = pd.DataFrame(names_list)
df.head()
# Out:
#         0
# 0  Lloris
# 1  Pavard
# 2  Varane
# 3  Umtiti
# 4   Lucas

# %%
df.to_csv('data/output/players_played_2018_round16_raw.csv')

# %%
print(len(df))
df_unique = df.drop_duplicates()
print(len(df_unique))
# Out:
# 278
# 235

# %%
df_unique.to_csv('data/output/players_played_2018_round16_unique.csv')
